# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array 
from keras.models import load_model
import numpy as np  
import matplotlib.pyplot as plt
import cv2 

# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(100, 100))	
	
	return img

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt




face_cascade = cv.CascadeClassifier()
face_cascade.load('face.xml')

model = load_model('face(1).h5')


frame = cv.imread('thanh3.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100   
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/10),x-int(w/10):x+w+2*int(h/10)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)
    # normalize to range [0,1]
    roi = roi.astype(float)
    cv.normalize(roi,roi,0, 1.0, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))    
#cv.imshow('video', frame)
    # close clip
    # if cv.waitKey(1) == ord('q'):
    #     break
# cap.release()
#cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# (100, 100)
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001F506095708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001F506095708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
frame = cv.imread('thanh.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100   
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/10),x-int(w/10):x+w+2*int(h/10)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 10)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)
    # normalize to range [0,1]
    roi = roi.astype(float)
    cv.normalize(roi,roi,0, 1.0, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'        
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),5)
    print(text)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# thanh

# %%
frame = cv.imread('thanh4.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100     
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/10),x-int(w/10):x+w+2*int(h/10)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)
    roi = roi.astype(float)
    cv.normalize(roi,roi,0, 1.0, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)   
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# thanh

# %%
frame = cv.imread('minh2.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100   
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)
 
    roi = cv.GaussianBlur(roi,(205,205),0,0)
    cv.normalize(roi,roi,0, 250, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,2,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)

# %%
frame = cv.imread('minh1.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100     
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)

    roi = cv.GaussianBlur(roi,(205,205),0,0)
    cv.normalize(roi,roi,0, 250, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)   
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# minh
# (100, 100)
# minh

# %%
frame = cv.imread('minh.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100     
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)

    roi = cv.GaussianBlur(roi,(205,205),0,0)
    cv.normalize(roi,roi,0, 250, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)    
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# minh

# %%
frame = cv.imread('minh4.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100     
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)

    roi = cv.GaussianBlur(roi,(205,205),0,0)
    cv.normalize(roi,roi,0, 250, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)    
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# minh

# %%
frame = cv.imread('minh6.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100   
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)

    roi = cv.GaussianBlur(roi,(25,25),0,0)
    cv.normalize(roi,roi,0, 255, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)    
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# minh

# %%
kernel = np.array([[-1,-1,-1], 
                       [-1, 9,-1],
                       [-1,-1,-1]])

frame = cv.imread('minh2.jpg', cv.IMREAD_COLOR)

gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
# detect human face
faces = face_cascade.detectMultiScale(gray)
# crop the face and resize to 100x100   
for (x,y,w,h) in faces:
    roi = gray[y-int(h/5):y+h+int(h/5),x-int(w/5):x+w+2*int(h/5)]
    cv.rectangle(frame, (x-int(w/10),y-int(h/5)), (x+w+2*int(h/10),y+h+int(h/10)), (0,0,255), 2)
    #roi =  cv.cvtColor(roi, cv.COLOR_BGR2GRAY)
    roi = cv.resize(roi,(100,100))
    print(roi.shape)
    roi = cv.filter2D(roi, -1, kernel)
    roi = cv.GaussianBlur(roi,(35,35),0,0)
    
    cv.normalize(roi,roi,0, 255, cv.NORM_MINMAX)
    # reshape
    roi = np.reshape(roi,(1,100,100,1))
    # predict
    result = np.argmax(model.predict(roi))
    
    if result == 0:
        text = 'minh'
    else:
        text = 'thanh'
    print(text)    
    cv.putText(frame, text,(x,y),cv.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
plt.imshow(roi.reshape(100,100))    
#plt.imshow( cv.cvtColor(frame, cv.COLOR_BGR2RGB))
# Out:
# (100, 100)
# minh
